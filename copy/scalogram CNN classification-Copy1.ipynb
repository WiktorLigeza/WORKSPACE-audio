# %%
import glob
import joblib
import os
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import tensorflow as tf
from xgboost import XGBClassifier
import xgboost
import pandas as pd
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### load and convert data (to: X, y)

# %%
data_base = glob.glob("/workspace/data/scalogram/*.npz")
len(data_base)
# Out:
# 5252

# %%
X = []
y = []
for sample in data_base:
    data = np.load(sample, allow_pickle=True)
    X.append(data['arr_0'])
    y.append(data['arr_1'])

# %% [markdown]
# ### data check

# %%
from PIL import Image
img = Image.fromarray(X[0])
print("label:", y[0])
img
# Out:
# label: 0
# <PIL.Image.Image image mode=L size=600x127 at 0x7F8703FD8ED0>

# %%
X_ = np.array(X)
y_ = np.array(y)
print(X_.shape)
print(y_.shape)
# Out:
# (5252, 127, 600)
# (5252,)

# %% [markdown]
# all good ;)

# %% [markdown]
# ### dump to joblib array - so its ready to use and easy to send

# %%
joblib.dump(X_, "/workspace/Wiktor Dawid/feats/Scalograms_feats/X.joblib")
joblib.dump(y_,"/workspace/Wiktor Dawid/feats/Scalograms_feats/y.joblib")
# Out:
# ['/workspace/Wiktor Dawid/feats/Scalograms_feats/y.joblib']

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Train

# %%
X_train = joblib.load("/workspace/Wiktor Dawid/feats/Scalograms_feats/X.joblib")
y_train = joblib.load("/workspace/Wiktor Dawid/feats/Scalograms_feats/y.joblib")

# %% [markdown]
# training will be done on my own computer - Wiktor - rtx flex here
