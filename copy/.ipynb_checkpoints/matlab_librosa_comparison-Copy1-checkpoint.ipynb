# %%
import json
import numpy as np
import os
import math
import librosa
from sklearn.model_selection import train_test_split
from Praat import Praat_IdeaLogic as PLogic
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import librosa.display
import glob
import joblib
import pandas as pd

# %%
def pad(X, size):
    shape = np.shape(X)
    padded_X = np.zeros((size))
    padded_X[:shape[0]] = X
    #rint(padded_X)
    return padded_X

# %%
new_X = pad(X, max_len)

# %%
new_X.shape
# Out:
# (140526,)

# %%
dir_name = glob.glob("../SincNet/data_lists/DATA/*.wav")

# %%
dir_name[:2]
# Out:
# ['../SincNet/data_lists/DATA/95-79-03-46-66-41-83.wav',
#  '../SincNet/data_lists/DATA/91-75-05-92-90-85-19.wav']

# %%
def return_max_len(dir_name):

    #progression bar 
    file_count = len(dir_name)
    bar = tqdm(desc="proccessing files", total=file_count)
    tot = 0
    max_val = 0
    
    for file in dir_name:
        bar.update(1)
        tot += 1
        
        #X.append(get_feats(audio_file))
        X, sample_rate = librosa.load(file,
                                res_type='kaiser_fast')
            
        if max_val < X.shape[0]:
            max_val = X.shape[0]
            
        
    return max_val

# %%
max_len = return_max_len(dir_name)
# Out:
# proccessing files:   0%|          | 0/5252 [00:00<?, ?it/s]

# %%
max_len
# Out:
# 140526

# %%
def extract(audio_file):
    name=os.path.basename(audio_file)
    name=os.path.splitext(name)[0]
    label = int(name[7:8]) - 1
    
    return label, audio_file
    
    
def get_feats(X, sr):
    #X, sample_rate = librosa.load(audio_file,
    #                             res_type='kaiser_fast')
    
    # mfcc 
    #print(X.shape)
    mfccs = librosa.feature.mfcc(y=X, sr=sr, n_mfcc=40)
    mfccs = mfccs.T
    #print(mfccs.shape)
    mfcc1D = np.mean(mfccs, axis=0)
    
    return mfcc1D, mfccs

def pad_all(dir_name, max_len):
    X1D = []
    X2D = []
    y = []
    
    #progression bar 
    file_count = len(dir_name)
    bar = tqdm(desc="proccessing files", total=file_count)
    tot = 0
    
    for file in dir_name:
        bar.update(1)
        tot += 1
        label, audio_file = extract(file)
        X, sample_rate = librosa.load(audio_file,
                              res_type='kaiser_fast')
        maxim = np.max(X)
        minim = np.min(X)
        if minim < -1:
            print("Lower than -1")
            print(minim)
            print(file)
            print("###########################################")
        if maxim > 1:
            print("Greater than 1")
            print(maxim)
            print(file)
            print("###########################################")
        #print(sample_rate)
        oneD, twoD = get_feats(pad(X, max_len), sample_rate)
        X1D.append(oneD)
        X2D.append(twoD)
        y.append(label)
        
    return X1D, X2D, y

# %%
X1D, X2D, y = pad_all(dir_name, 140526)
# Out:
# proccessing files:   0%|          | 0/5252 [00:00<?, ?it/s]
# Lower than -1
# -1.0024046
# ../SincNet/data_lists/DATA/03-01-03-02-02-01-20.wav
# ###########################################
# Lower than -1
# -1.0007285
# ../SincNet/data_lists/DATA/83-86-03-25-77-21-97.wav
# ###########################################
# Lower than -1
# -1.0021683
# ../SincNet/data_lists/DATA/44-56-08-32-61-65-40.wav
# ###########################################
# Lower than -1
# -1.0032476
# ../SincNet/data_lists/DATA/19-60-04-33-41-74-32.wav
# ###########################################
# Greater than 1
# 1.0050837
# ../SincNet/data_lists/DATA/95-77-05-92-69-91-47.wav
# ###########################################
# Lower than -1
# -1.0008792
# ../SincNet/data_lists/DATA/03-01-07-01-02-01-05.wav
# ###########################################
# Greater than 1
# 1.0003626
# ../SincNet/data_lists/DATA/03-02-06-01-01-01-17.wav
# ###########################################
# Lower than -1
# -1.0107014
# ../SincNet/data_lists/DATA/42-25-04-68-56-87-34.wav
# ###########################################
# Lower than -1
# -1.0134246
# ../SincNet/data_lists/DATA/23-55-08-41-42-30-83.wav
# ###########################################
# Lower than -1
# -1.0050789
# ../SincNet/data_lists/DATA/03-01-02-01-01-02-16.wav
# ###########################################
# Greater than 1
# 1.0016081
# ../SincNet/data_lists/DATA/03-02-01-01-02-02-03.wav
# ###########################################
# Greater than 1
# 1.0018495
# ../SincNet/data_lists/DATA/03-02-04-02-02-02-20.wav
# ###########################################
# Lower than -1
# -1.0068842
# ../SincNet/data_lists/DATA/77-69-05-45-91-96-53.wav
# ###########################################
# Lower than -1
# -1.0174721
# ../SincNet/data_lists/DATA/13-22-05-70-61-75-94.wav
# ###########################################
# Lower than -1
# -1.0000365
# ../SincNet/data_lists/DATA/14-67-04-93-94-88-59.wav
# ###########################################
# Lower than -1
# -1.0036944
# ../SincNet/data_lists/DATA/62-18-04-27-42-82-45.wav
# ###########################################
# Greater than 1
# 1.0030199
# ../SincNet/data_lists/DATA/67-32-06-38-84-48-68.wav
# ###########################################
# Lower than -1
# -1.0129211
# ../SincNet/data_lists/DATA/37-94-05-44-11-57-89.wav
# ###########################################
# Greater than 1
# 1.0072972
# ../SincNet/data_lists/DATA/54-86-01-94-28-14-36.wav
# ###########################################
# Lower than -1
# -1.0099527
# ../SincNet/data_lists/DATA/40-43-01-65-11-86-79.wav
# ###########################################
# Lower than -1
# -1.0025339
# ../SincNet/data_lists/DATA/03-02-01-01-02-02-09.wav
# ###########################################
# Lower than -1
# -1.0007848
# ../SincNet/data_lists/DATA/50-41-05-79-44-26-98.wav
# ###########################################
# Lower than -1
# -1.0035566
# ../SincNet/data_lists/DATA/86-82-04-77-64-61-84.wav
# ###########################################
# Lower than -1
# -1.0052418
# ../SincNet/data_lists/DATA/65-80-08-18-94-83-76.wav
# ###########################################
# Lower than -1
# -1.0017484
# ../SincNet/data_lists/DATA/03-02-02-01-02-02-10.wav
# ###########################################
# Greater than 1
# 1.0161647
# ../SincNet/data_lists/DATA/25-22-05-21-23-92-48.wav
# ###########################################
# Greater than 1
# 1.0092561
# ../SincNet/data_lists/DATA/03-01-05-02-01-01-09.wav
# ###########################################
# Lower than -1
# -1.0019759
# ../SincNet/data_lists/DATA/31-10-05-51-64-70-42.wav
# ###########################################
# Greater than 1
# 1.0189053
# ../SincNet/data_lists/DATA/03-01-07-02-02-02-21.wav
# ###########################################
# Lower than -1
# -1.0083776
# ../SincNet/data_lists/DATA/56-86-06-32-28-36-23.wav
# ###########################################
# Lower than -1
# -1.0013871
# ../SincNet/data_lists/DATA/80-68-04-81-76-37-40.wav
# ###########################################
# Greater than 1
# 1.0065362
# ../SincNet/data_lists/DATA/03-02-05-01-02-01-06.wav
# ###########################################
# Lower than -1
# -1.0083296
# ../SincNet/data_lists/DATA/39-77-06-27-19-24-47.wav
# ###########################################
# Lower than -1
# -1.0046525
# ../SincNet/data_lists/DATA/41-78-03-76-72-19-95.wav
# ###########################################
# Lower than -1
# -1.0053549
# ../SincNet/data_lists/DATA/03-01-08-02-01-02-17.wav
# ###########################################
# Lower than -1
# -1.0047889
# ../SincNet/data_lists/DATA/42-62-04-69-16-75-30.wav
# ###########################################
# Greater than 1
# 1.0074583
# ../SincNet/data_lists/DATA/03-02-05-01-01-02-03.wav
# ###########################################
# Greater than 1
# 1.009026
# ../SincNet/data_lists/DATA/69-47-03-84-83-19-77.wav
# ###########################################
# Lower than -1
# -1.005902
# ../SincNet/data_lists/DATA/73-30-03-27-70-91-33.wav
# ###########################################
# Lower than -1
# -1.0065215
# ../SincNet/data_lists/DATA/71-68-05-84-23-86-18.wav
# ###########################################
# Greater than 1
# 1.0010833
# ../SincNet/data_lists/DATA/03-01-03-01-01-01-01.wav
# ###########################################
# Lower than -1
# -1.0192555
# ../SincNet/data_lists/DATA/48-21-05-59-74-75-36.wav
# ###########################################
# Greater than 1
# 1.0329831
# ../SincNet/data_lists/DATA/37-25-07-12-77-81-31.wav
# ###########################################
# Lower than -1
# -1.0259614
# ../SincNet/data_lists/DATA/47-81-04-27-86-16-97.wav
# ###########################################
# Greater than 1
# 1.0018684
# ../SincNet/data_lists/DATA/65-77-08-52-81-47-20.wav
# ###########################################
# Greater than 1
# 1.0080562
# ../SincNet/data_lists/DATA/84-54-08-25-10-83-46.wav
# ###########################################
# Greater than 1
# 1.0004083
# ../SincNet/data_lists/DATA/69-17-06-49-68-35-98.wav
# ###########################################
# Greater than 1
# 1.0094754
# ../SincNet/data_lists/DATA/61-89-08-92-62-68-47.wav
# ###########################################
# Greater than 1
# 1.0015554
# ../SincNet/data_lists/DATA/03-01-03-01-02-02-17.wav
# ###########################################
# Lower than -1
# -1.0141805
# ../SincNet/data_lists/DATA/39-87-06-18-54-43-45.wav
# ###########################################
# Lower than -1
# -1.0011075
# ../SincNet/data_lists/DATA/19-73-08-80-77-97-65.wav
# ###########################################
# Greater than 1
# 1.0024389
# ../SincNet/data_lists/DATA/03-02-04-02-01-01-05.wav
# ###########################################
# Greater than 1
# 1.0068772
# ../SincNet/data_lists/DATA/50-35-03-69-29-27-23.wav
# ###########################################
# Greater than 1
# 1.00761
# ../SincNet/data_lists/DATA/03-02-01-01-01-02-05.wav
# ###########################################
# Greater than 1
# 1.0184518
# ../SincNet/data_lists/DATA/45-28-05-37-67-46-34.wav
# ###########################################
# Lower than -1
# -1.0007575
# ../SincNet/data_lists/DATA/38-53-01-50-70-37-83.wav
# ###########################################
# Greater than 1
# 1.0213399
# ../SincNet/data_lists/DATA/20-26-06-30-10-24-69.wav
# ###########################################
# Lower than -1
# -1.0073768
# ../SincNet/data_lists/DATA/03-02-04-02-01-02-23.wav
# ###########################################
# Greater than 1
# 1.0022812
# ../SincNet/data_lists/DATA/03-02-02-02-02-02-07.wav
# ###########################################
# Greater than 1
# 1.0008576
# ../SincNet/data_lists/DATA/03-02-05-01-01-01-21.wav
# ###########################################
# Greater than 1
# 1.0016817
# ../SincNet/data_lists/DATA/03-02-03-01-02-02-09.wav
# ###########################################
# Lower than -1
# -1.0028342
# ../SincNet/data_lists/DATA/96-79-08-52-60-88-89.wav
# ###########################################
# Lower than -1
# -1.01403
# ../SincNet/data_lists/DATA/29-50-03-71-75-95-45.wav
# ###########################################
# Lower than -1
# -1.0016315
# ../SincNet/data_lists/DATA/50-66-03-30-11-13-85.wav
# ###########################################
# Lower than -1
# -1.0179787
# ../SincNet/data_lists/DATA/63-96-04-71-70-62-61.wav
# ###########################################
# Greater than 1
# 1.0023172
# ../SincNet/data_lists/DATA/62-94-07-46-33-54-58.wav
# ###########################################
# Lower than -1
# -1.0056456
# ../SincNet/data_lists/DATA/46-45-04-85-51-30-69.wav
# ###########################################
# Lower than -1
# -1.0022683
# ../SincNet/data_lists/DATA/03-01-03-02-01-01-05.wav
# ###########################################
# Lower than -1
# -1.0037773
# ../SincNet/data_lists/DATA/63-68-03-14-59-82-11.wav
# ###########################################
# Lower than -1
# -1.0000536
# ../SincNet/data_lists/DATA/52-27-04-14-21-95-55.wav
# ###########################################
# Lower than -1
# -1.0003911
# ../SincNet/data_lists/DATA/83-71-03-25-44-31-63.wav
# ###########################################
# Greater than 1
# 1.012139
# ../SincNet/data_lists/DATA/03-01-05-02-01-02-17.wav
# ###########################################
# Lower than -1
# -1.0035836
# ../SincNet/data_lists/DATA/10-45-03-16-12-95-73.wav
# ###########################################
# Greater than 1
# 1.0060214
# ../SincNet/data_lists/DATA/59-25-07-74-78-10-35.wav
# ###########################################
# Lower than -1
# -1.0025454
# ../SincNet/data_lists/DATA/03-01-04-02-02-01-09.wav
# ###########################################
# Lower than -1
# -1.0039157
# ../SincNet/data_lists/DATA/38-69-05-63-62-64-92.wav
# ###########################################
# Greater than 1
# 1.0011641
# ../SincNet/data_lists/DATA/80-18-07-48-52-31-41.wav
# ###########################################
# Greater than 1
# 1.0202775
# ../SincNet/data_lists/DATA/77-81-05-85-42-66-75.wav
# ###########################################
# Lower than -1
# -1.0010308
# ../SincNet/data_lists/DATA/13-69-08-30-46-56-84.wav
# ###########################################
# Lower than -1
# -1.0038283
# ../SincNet/data_lists/DATA/22-79-08-67-57-88-34.wav
# ###########################################
# Lower than -1
# -1.0087134
# ../SincNet/data_lists/DATA/93-42-03-85-47-58-90.wav
# ###########################################
# Lower than -1
# -1.0026338
# ../SincNet/data_lists/DATA/50-69-01-23-81-62-82.wav
# ###########################################
# Lower than -1
# -1.0153707
# ../SincNet/data_lists/DATA/73-92-04-55-90-52-36.wav
# ###########################################
# Greater than 1
# 1.0057992
# ../SincNet/data_lists/DATA/23-80-05-22-17-40-67.wav
# ###########################################
# Lower than -1
# -1.0021272
# ../SincNet/data_lists/DATA/11-78-04-96-83-68-30.wav
# ###########################################
# Lower than -1
# -1.0003932
# ../SincNet/data_lists/DATA/19-57-05-55-95-29-50.wav
# ###########################################
# Greater than 1
# 1.00187
# ../SincNet/data_lists/DATA/27-29-01-21-62-42-80.wav
# ###########################################
# Lower than -1
# -1.0041252
# ../SincNet/data_lists/DATA/89-34-05-14-58-10-88.wav
# ###########################################
# Lower than -1
# -1.0018834
# ../SincNet/data_lists/DATA/78-86-08-34-92-89-98.wav
# ###########################################
# Lower than -1
# -1.0001233
# ../SincNet/data_lists/DATA/91-37-04-73-16-31-10.wav
# ###########################################
# Lower than -1
# -1.0012729
# ../SincNet/data_lists/DATA/27-52-01-56-20-80-91.wav
# ###########################################
# Lower than -1
# -1.0011746
# ../SincNet/data_lists/DATA/03-01-03-01-02-02-02.wav
# ###########################################
# Lower than -1
# -1.0062273
# ../SincNet/data_lists/DATA/65-95-01-72-81-41-12.wav
# ###########################################
# Lower than -1
# -1.0128057
# ../SincNet/data_lists/DATA/70-20-03-65-17-44-76.wav
# ###########################################
# Greater than 1
# 1.0053003
# ../SincNet/data_lists/DATA/60-44-01-75-95-97-82.wav
# ###########################################
# Lower than -1
# -1.0062898
# ../SincNet/data_lists/DATA/95-28-05-52-48-11-82.wav
# ###########################################
# Lower than -1
# -1.0026907
# ../SincNet/data_lists/DATA/65-28-01-62-90-27-81.wav
# ###########################################
# Lower than -1
# -1.0017936
# ../SincNet/data_lists/DATA/33-93-03-83-32-62-69.wav
# ###########################################
# Greater than 1
# 1.001219
# ../SincNet/data_lists/DATA/03-02-04-02-01-01-02.wav
# ###########################################
# Lower than -1
# -1.0012147
# ../SincNet/data_lists/DATA/03-01-08-02-02-02-07.wav
# ###########################################
# Lower than -1
# -1.0030117
# ../SincNet/data_lists/DATA/69-88-03-78-83-71-37.wav
# ###########################################
# Greater than 1
# 1.0082588
# ../SincNet/data_lists/DATA/27-35-07-90-75-30-11.wav
# ###########################################
# Lower than -1
# -1.0052459
# ../SincNet/data_lists/DATA/72-26-08-39-29-96-74.wav
# ###########################################
# Lower than -1
# -1.0008515
# ../SincNet/data_lists/DATA/41-97-03-78-49-26-63.wav
# ###########################################
# Greater than 1
# 1.0052812
# ../SincNet/data_lists/DATA/03-02-03-01-02-01-08.wav
# ###########################################
# Greater than 1
# 1.0129042
# ../SincNet/data_lists/DATA/03-01-06-02-01-01-19.wav
# ###########################################
# Greater than 1
# 1.0183296
# ../SincNet/data_lists/DATA/03-02-05-01-01-02-01.wav
# ###########################################
# Lower than -1
# -1.0077997
# ../SincNet/data_lists/DATA/92-16-08-17-71-57-21.wav
# ###########################################
# Greater than 1
# 1.0023674
# ../SincNet/data_lists/DATA/03-01-03-01-01-02-21.wav
# ###########################################
# Greater than 1
# 1.004017
# ../SincNet/data_lists/DATA/83-69-07-42-92-17-66.wav
# ###########################################
# Lower than -1
# -1.0023417
# ../SincNet/data_lists/DATA/90-85-08-54-13-86-29.wav
# ###########################################
# Lower than -1
# -1.0012194
# ../SincNet/data_lists/DATA/97-98-06-90-86-44-83.wav
# ###########################################
# Greater than 1
# 1.0163426
# ../SincNet/data_lists/DATA/24-65-08-20-87-33-48.wav
# ###########################################
# Greater than 1
# 1.0167806
# ../SincNet/data_lists/DATA/51-31-07-92-96-10-98.wav
# ###########################################
# Greater than 1
# 1.0124015
# ../SincNet/data_lists/DATA/88-77-06-64-98-10-19.wav
# ###########################################
# Greater than 1
# 1.0055516
# ../SincNet/data_lists/DATA/61-86-01-54-77-79-43.wav
# ###########################################
# Greater than 1
# 1.0063212
# ../SincNet/data_lists/DATA/38-69-05-62-42-28-10.wav
# ###########################################
# Lower than -1
# -1.0118431
# ../SincNet/data_lists/DATA/47-66-06-82-64-53-19.wav
# ###########################################
# Lower than -1
# -1.0050825
# ../SincNet/data_lists/DATA/26-24-06-73-21-54-30.wav
# ###########################################
# Greater than 1
# 1.0063345
# ../SincNet/data_lists/DATA/12-53-05-22-77-89-70.wav
# ###########################################
# Lower than -1
# -1.0042386
# ../SincNet/data_lists/DATA/75-33-04-87-37-72-53.wav
# ###########################################
# Lower than -1
# -1.0046928
# ../SincNet/data_lists/DATA/89-36-05-97-34-46-16.wav
# ###########################################
# Lower than -1
# -1.0059379
# ../SincNet/data_lists/DATA/82-24-06-57-83-29-64.wav
# ###########################################
# Lower than -1
# -1.0040843
# ../SincNet/data_lists/DATA/71-81-03-83-50-67-87.wav
# ###########################################
# Greater than 1
# 1.0032008
# ../SincNet/data_lists/DATA/03-02-02-02-01-02-22.wav
# ###########################################
# Greater than 1
# 1.0046622
# ../SincNet/data_lists/DATA/03-01-07-02-02-02-10.wav
# ###########################################
# Lower than -1
# -1.0024018
# ../SincNet/data_lists/DATA/53-54-01-79-92-10-46.wav
# ###########################################
# Lower than -1
# -1.0071788
# ../SincNet/data_lists/DATA/18-29-06-64-55-36-71.wav
# ###########################################
# Greater than 1
# 1.002715
# ../SincNet/data_lists/DATA/26-20-05-93-14-33-77.wav
# ###########################################
# Lower than -1
# -1.0064441
# ../SincNet/data_lists/DATA/68-75-08-87-45-55-59.wav
# ###########################################
# Lower than -1
# -1.0018113
# ../SincNet/data_lists/DATA/11-50-06-48-22-44-79.wav
# ###########################################
# Lower than -1
# -1.0043073
# ../SincNet/data_lists/DATA/22-36-05-26-48-38-76.wav
# ###########################################
# Greater than 1
# 1.0041634
# ../SincNet/data_lists/DATA/03-02-04-02-01-01-13.wav
# ###########################################
# Greater than 1
# 1.0049394
# ../SincNet/data_lists/DATA/94-78-06-82-89-47-35.wav
# ###########################################
# Lower than -1
# -1.0138987
# ../SincNet/data_lists/DATA/03-01-08-02-01-02-07.wav
# ###########################################
# Lower than -1
# -1.0161042
# ../SincNet/data_lists/DATA/64-43-03-11-70-76-61.wav
# ###########################################
# Lower than -1
# -1.0020516
# ../SincNet/data_lists/DATA/40-45-01-93-55-83-28.wav
# ###########################################
# Lower than -1
# -1.0053378
# ../SincNet/data_lists/DATA/57-48-05-76-67-51-90.wav
# ###########################################
# Greater than 1
# 1.0276093
# ../SincNet/data_lists/DATA/21-97-08-55-22-41-91.wav
# ###########################################
# Lower than -1
# -1.0073496
# ../SincNet/data_lists/DATA/54-70-01-17-85-16-22.wav
# ###########################################
# Lower than -1
# -1.0060276
# ../SincNet/data_lists/DATA/49-48-07-44-69-30-71.wav
# ###########################################
# Lower than -1
# -1.0003113
# ../SincNet/data_lists/DATA/63-51-03-42-52-16-47.wav
# ###########################################
# Lower than -1
# -1.0072501
# ../SincNet/data_lists/DATA/58-13-05-85-84-67-42.wav
# ###########################################
# Lower than -1
# -1.0021214
# ../SincNet/data_lists/DATA/88-27-07-80-78-24-16.wav
# ###########################################
# Greater than 1
# 1.0129913
# ../SincNet/data_lists/DATA/03-01-04-01-02-02-23.wav
# ###########################################
# Greater than 1
# 1.0014108
# ../SincNet/data_lists/DATA/03-01-01-01-02-02-21.wav
# ###########################################
# Lower than -1
# -1.003335
# ../SincNet/data_lists/DATA/59-67-04-84-15-79-61.wav
# ###########################################
# Lower than -1
# -1.0006692
# ../SincNet/data_lists/DATA/29-96-01-90-92-51-22.wav
# ###########################################
# Lower than -1
# -1.0056108
# ../SincNet/data_lists/DATA/03-01-06-02-01-02-05.wav
# ###########################################
# Lower than -1
# -1.0045573
# ../SincNet/data_lists/DATA/78-63-05-13-71-61-92.wav
# ###########################################
# Lower than -1
# -1.0007968
# ../SincNet/data_lists/DATA/83-76-03-24-91-98-77.wav
# ###########################################
# Lower than -1
# -1.0009156
# ../SincNet/data_lists/DATA/26-19-03-43-22-20-55.wav
# ###########################################
# Greater than 1
# 1.0190766
# ../SincNet/data_lists/DATA/75-62-07-29-74-94-88.wav
# ###########################################
# Lower than -1
# -1.0145166
# ../SincNet/data_lists/DATA/36-94-08-50-37-27-76.wav
# ###########################################
# Lower than -1
# -1.0034782
# ../SincNet/data_lists/DATA/21-10-07-86-80-65-30.wav
# ###########################################
# Lower than -1
# -1.0028802
# ../SincNet/data_lists/DATA/03-02-01-01-01-02-11.wav
# ###########################################
# Lower than -1
# -1.0048493
# ../SincNet/data_lists/DATA/62-68-08-51-42-57-56.wav
# ###########################################
# Lower than -1
# -1.0184749
# ../SincNet/data_lists/DATA/03-02-04-02-01-01-08.wav
# ###########################################
# Lower than -1
# -1.0011702
# ../SincNet/data_lists/DATA/18-55-06-31-13-11-52.wav
# ###########################################
# Lower than -1
# -1.0032234
# ../SincNet/data_lists/DATA/49-66-06-29-42-78-48.wav
# ###########################################
# Lower than -1
# -1.0033188
# ../SincNet/data_lists/DATA/75-86-04-92-29-56-49.wav
# ###########################################
# Lower than -1
# -1.0025585
# ../SincNet/data_lists/DATA/83-19-04-89-31-41-57.wav
# ###########################################
# Greater than 1
# 1.0040137
# ../SincNet/data_lists/DATA/03-02-02-01-01-01-16.wav
# ###########################################
# Lower than -1
# -1.0022054
# ../SincNet/data_lists/DATA/64-86-05-92-75-55-98.wav
# ###########################################
# Lower than -1
# -1.0217379
# ../SincNet/data_lists/DATA/33-78-01-20-30-61-93.wav
# ###########################################
# Lower than -1
# -1.0041076
# ../SincNet/data_lists/DATA/69-63-06-73-84-86-91.wav
# ###########################################
# Lower than -1
# -1.0057688
# ../SincNet/data_lists/DATA/03-01-07-02-01-02-11.wav
# ###########################################
# Lower than -1
# -1.0052099
# ../SincNet/data_lists/DATA/41-91-03-87-66-88-54.wav
# ###########################################
# Greater than 1
# 1.0063573
# ../SincNet/data_lists/DATA/86-96-07-87-21-41-25.wav
# ###########################################
# Lower than -1
# -1.0092729
# ../SincNet/data_lists/DATA/83-68-04-56-98-79-24.wav
# ###########################################
# Lower than -1
# -1.0008377
# ../SincNet/data_lists/DATA/29-38-03-55-21-65-49.wav
# ###########################################
# Lower than -1
# -1.0078304
# ../SincNet/data_lists/DATA/49-93-05-79-50-87-90.wav
# ###########################################
# Lower than -1
# -1.0123347
# ../SincNet/data_lists/DATA/66-76-04-50-53-44-62.wav
# ###########################################
# Greater than 1
# 1.0055368
# ../SincNet/data_lists/DATA/03-01-05-02-01-01-23.wav
# ###########################################
# Lower than -1
# -1.0150368
# ../SincNet/data_lists/DATA/03-02-04-01-01-02-23.wav
# ###########################################
# Lower than -1
# -1.0016892
# ../SincNet/data_lists/DATA/79-70-07-23-80-46-36.wav
# ###########################################
# Lower than -1
# -1.0048709
# ../SincNet/data_lists/DATA/97-90-08-62-92-54-84.wav
# ###########################################
# Lower than -1
# -1.0013272
# ../SincNet/data_lists/DATA/36-54-06-19-57-56-51.wav
# ###########################################
# Lower than -1
# -1.0031179
# ../SincNet/data_lists/DATA/93-71-03-62-90-18-38.wav
# ###########################################
# Lower than -1
# -1.0028348
# ../SincNet/data_lists/DATA/57-90-04-52-46-63-37.wav
# ###########################################
# Lower than -1
# -1.0055511
# ../SincNet/data_lists/DATA/81-69-08-41-98-36-19.wav
# ###########################################
# Lower than -1
# -1.006005
# ../SincNet/data_lists/DATA/19-82-04-64-29-90-69.wav
# ###########################################
# Lower than -1
# -1.0148752
# ../SincNet/data_lists/DATA/65-13-05-10-30-18-69.wav
# ###########################################
# Lower than -1
# -1.0048108
# ../SincNet/data_lists/DATA/92-21-06-75-53-46-68.wav
# ###########################################
# Lower than -1
# -1.0003338
# ../SincNet/data_lists/DATA/03-02-02-02-02-01-11.wav
# ###########################################
# Lower than -1
# -1.0275904
# ../SincNet/data_lists/DATA/51-60-05-46-71-76-17.wav
# ###########################################
# Lower than -1
# -1.0007472
# ../SincNet/data_lists/DATA/03-02-01-01-01-02-09.wav
# ###########################################
# Lower than -1
# -1.0012723
# ../SincNet/data_lists/DATA/51-65-04-77-45-62-61.wav
# ###########################################
# Greater than 1
# 1.001675
# ../SincNet/data_lists/DATA/03-01-04-02-02-01-15.wav
# ###########################################
# Lower than -1
# -1.0140237
# ../SincNet/data_lists/DATA/69-71-05-85-61-81-86.wav
# ###########################################
# Greater than 1
# 1.0047544
# ../SincNet/data_lists/DATA/69-71-05-85-61-81-86.wav
# ###########################################
# Lower than -1
# -1.002889
# ../SincNet/data_lists/DATA/03-01-02-01-02-01-03.wav
# ###########################################
# Greater than 1
# 1.0083922
# ../SincNet/data_lists/DATA/03-01-08-01-02-02-04.wav
# ###########################################
# Greater than 1
# 1.0063038
# ../SincNet/data_lists/DATA/03-02-06-02-01-02-16.wav
# ###########################################
# Lower than -1
# -1.0015057
# ../SincNet/data_lists/DATA/25-15-01-80-94-92-31.wav
# ###########################################
# Greater than 1
# 1.0108379
# ../SincNet/data_lists/DATA/43-68-05-14-61-66-88.wav
# ###########################################
# Lower than -1
# -1.0016673
# ../SincNet/data_lists/DATA/91-55-04-82-47-83-88.wav
# ###########################################
# Lower than -1
# -1.022321
# ../SincNet/data_lists/DATA/35-38-04-58-81-57-65.wav
# ###########################################
# Lower than -1
# -1.000869
# ../SincNet/data_lists/DATA/22-90-08-52-70-93-91.wav
# ###########################################
# Greater than 1
# 1.0000505
# ../SincNet/data_lists/DATA/03-02-01-01-01-01-09.wav
# ###########################################
# Greater than 1
# 1.0033448
# ../SincNet/data_lists/DATA/03-02-02-01-02-01-13.wav
# ###########################################
# Lower than -1
# -1.0002811
# ../SincNet/data_lists/DATA/33-69-07-43-36-79-55.wav
# ###########################################
# Lower than -1
# -1.0037061
# ../SincNet/data_lists/DATA/64-90-04-69-18-54-36.wav
# ###########################################
# Greater than 1
# 1.0284005
# ../SincNet/data_lists/DATA/64-90-04-69-18-54-36.wav
# ###########################################
# Lower than -1
# -1.0055385
# ../SincNet/data_lists/DATA/34-45-07-47-84-90-11.wav
# ###########################################
# Lower than -1
# -1.010475
# ../SincNet/data_lists/DATA/92-57-04-84-91-77-22.wav
# ###########################################
# Greater than 1
# 1.0088118
# ../SincNet/data_lists/DATA/03-01-03-01-01-01-08.wav
# ###########################################
# Lower than -1
# -1.017098
# ../SincNet/data_lists/DATA/03-01-05-01-01-01-13.wav
# ###########################################
# Lower than -1
# -1.001437
# ../SincNet/data_lists/DATA/95-51-01-62-97-75-81.wav
# ###########################################
# Lower than -1
# -1.0024831
# ../SincNet/data_lists/DATA/93-41-01-40-44-14-15.wav
# ###########################################
# Lower than -1
# -1.0063614
# ../SincNet/data_lists/DATA/18-89-07-79-30-37-85.wav
# ###########################################
# Lower than -1
# -1.0065243
# ../SincNet/data_lists/DATA/47-68-04-29-72-74-56.wav
# ###########################################
# Lower than -1
# -1.0103477
# ../SincNet/data_lists/DATA/84-72-03-46-54-85-97.wav
# ###########################################
# Greater than 1
# 1.0162969
# ../SincNet/data_lists/DATA/03-01-05-01-02-02-20.wav
# ###########################################
# Greater than 1
# 1.0058074
# ../SincNet/data_lists/DATA/03-01-01-01-02-01-01.wav
# ###########################################
# Greater than 1
# 1.0038564
# ../SincNet/data_lists/DATA/03-01-07-01-01-02-24.wav
# ###########################################
# Greater than 1
# 1.0046302
# ../SincNet/data_lists/DATA/51-22-07-92-78-15-35.wav
# ###########################################
# Greater than 1
# 1.0004592
# ../SincNet/data_lists/DATA/03-02-06-02-02-01-24.wav
# ###########################################
# Greater than 1
# 1.0025104
# ../SincNet/data_lists/DATA/03-01-08-01-01-01-01.wav
# ###########################################
# Lower than -1
# -1.011412
# ../SincNet/data_lists/DATA/60-29-08-43-37-94-18.wav
# ###########################################
# Lower than -1
# -1.0048937
# ../SincNet/data_lists/DATA/24-47-06-38-85-68-78.wav
# ###########################################
# Lower than -1
# -1.0084955
# ../SincNet/data_lists/DATA/20-98-06-65-11-12-51.wav
# ###########################################
# Lower than -1
# -1.0052814
# ../SincNet/data_lists/DATA/89-67-07-16-98-73-17.wav
# ###########################################
# Greater than 1
# 1.0257335
# ../SincNet/data_lists/DATA/45-94-07-85-32-56-82.wav
# ###########################################
# Lower than -1
# -1.004969
# ../SincNet/data_lists/DATA/82-67-06-40-45-78-89.wav
# ###########################################
# Lower than -1
# -1.0026561
# ../SincNet/data_lists/DATA/03-01-02-01-01-01-19.wav
# ###########################################
# Greater than 1
# 1.0037811
# ../SincNet/data_lists/DATA/96-31-04-24-50-27-19.wav
# ###########################################
# Greater than 1
# 1.0080699
# ../SincNet/data_lists/DATA/03-01-03-02-01-01-15.wav
# ###########################################
# Lower than -1
# -1.0142341
# ../SincNet/data_lists/DATA/03-02-04-01-02-02-20.wav
# ###########################################
# Lower than -1
# -1.0069276
# ../SincNet/data_lists/DATA/39-19-05-48-36-84-12.wav
# ###########################################
# Lower than -1
# -1.0073426
# ../SincNet/data_lists/DATA/71-45-06-53-72-64-22.wav
# ###########################################
# Lower than -1
# -1.0046859
# ../SincNet/data_lists/DATA/51-65-01-44-69-97-88.wav
# ###########################################
# Greater than 1
# 1.0029964
# ../SincNet/data_lists/DATA/03-01-08-02-02-01-16.wav
# ###########################################
# Greater than 1
# 1.0019834
# ../SincNet/data_lists/DATA/03-02-06-01-02-02-01.wav
# ###########################################
# Lower than -1
# -1.0022696
# ../SincNet/data_lists/DATA/88-26-04-28-97-25-92.wav
# ###########################################
# Lower than -1
# -1.0007805
# ../SincNet/data_lists/DATA/94-43-08-39-50-33-59.wav
# ###########################################
# Greater than 1
# 1.0022731
# ../SincNet/data_lists/DATA/03-02-03-01-01-01-14.wav
# ###########################################
# Greater than 1
# 1.0041568
# ../SincNet/data_lists/DATA/03-01-05-02-02-01-14.wav
# ###########################################
# Lower than -1
# -1.0007248
# ../SincNet/data_lists/DATA/28-41-05-35-78-96-14.wav
# ###########################################
# Greater than 1
# 1.0095539
# ../SincNet/data_lists/DATA/03-02-05-02-02-01-24.wav
# ###########################################
# Lower than -1
# -1.0079467
# ../SincNet/data_lists/DATA/52-35-03-66-22-20-24.wav
# ###########################################
# Lower than -1
# -1.0032268
# ../SincNet/data_lists/DATA/03-02-06-01-01-01-08.wav
# ###########################################
# Lower than -1
# -1.0016714
# ../SincNet/data_lists/DATA/96-87-06-74-15-26-32.wav
# ###########################################
# Lower than -1
# -1.001674
# ../SincNet/data_lists/DATA/19-25-08-76-61-84-38.wav
# ###########################################
# Greater than 1
# 1.0086589
# ../SincNet/data_lists/DATA/03-02-05-02-01-02-08.wav
# ###########################################
# Lower than -1
# -1.0008246
# ../SincNet/data_lists/DATA/03-02-04-02-02-02-15.wav
# ###########################################
# Lower than -1
# -1.0005091
# ../SincNet/data_lists/DATA/51-87-06-41-50-22-98.wav
# ###########################################
# Greater than 1
# 1.0032413
# ../SincNet/data_lists/DATA/03-01-08-01-01-02-07.wav
# ###########################################
# Greater than 1
# 1.0033226
# ../SincNet/data_lists/DATA/03-02-01-01-01-01-08.wav
# ###########################################
# Lower than -1
# -1.001141
# ../SincNet/data_lists/DATA/03-02-04-02-01-01-07.wav
# ###########################################
# Greater than 1
# 1.0042835
# ../SincNet/data_lists/DATA/34-56-05-10-88-97-43.wav
# ###########################################
# Lower than -1
# -1.0075202
# ../SincNet/data_lists/DATA/61-78-04-62-98-21-39.wav
# ###########################################
# Lower than -1
# -1.00066
# ../SincNet/data_lists/DATA/64-31-03-81-15-93-70.wav
# ###########################################
# Greater than 1
# 1.0040581
# ../SincNet/data_lists/DATA/03-01-04-02-01-01-12.wav
# ###########################################
# Lower than -1
# -1.0015043
# ../SincNet/data_lists/DATA/46-47-08-45-94-11-69.wav
# ###########################################
# Lower than -1
# -1.0004611
# ../SincNet/data_lists/DATA/40-53-04-10-34-91-85.wav
# ###########################################
# Lower than -1
# -1.0039471
# ../SincNet/data_lists/DATA/11-59-03-86-50-77-28.wav
# ###########################################
# Greater than 1
# 1.0143803
# ../SincNet/data_lists/DATA/35-24-05-13-86-80-90.wav
# ###########################################
# Lower than -1
# -1.0033691
# ../SincNet/data_lists/DATA/95-35-08-53-24-14-13.wav
# ###########################################
# Greater than 1
# 1.0035146
# ../SincNet/data_lists/DATA/03-02-03-02-01-02-01.wav
# ###########################################
# Greater than 1
# 1.0294217
# ../SincNet/data_lists/DATA/10-35-07-43-83-36-73.wav
# ###########################################
# Lower than -1
# -1.0089709
# ../SincNet/data_lists/DATA/84-48-07-53-70-81-14.wav
# ###########################################
# Greater than 1
# 1.0574758
# ../SincNet/data_lists/DATA/48-73-07-62-57-91-65.wav
# ###########################################
# Lower than -1
# -1.002231
# ../SincNet/data_lists/DATA/25-98-03-46-24-20-71.wav
# ###########################################
# Lower than -1
# -1.0055187
# ../SincNet/data_lists/DATA/85-36-08-86-29-10-39.wav
# ###########################################
# Greater than 1
# 1.0004748
# ../SincNet/data_lists/DATA/03-02-02-02-01-01-06.wav
# ###########################################
# Lower than -1
# -1.008695
# ../SincNet/data_lists/DATA/76-47-06-42-45-62-94.wav
# ###########################################
# Lower than -1
# -1.0004698
# ../SincNet/data_lists/DATA/40-75-03-51-81-25-16.wav
# ###########################################
# Lower than -1
# -1.0006407
# ../SincNet/data_lists/DATA/20-62-04-31-52-78-13.wav
# ###########################################
# Lower than -1
# -1.0074556
# ../SincNet/data_lists/DATA/25-37-01-38-78-77-98.wav
# ###########################################
# Lower than -1
# -1.0015093
# ../SincNet/data_lists/DATA/03-02-06-02-02-01-19.wav
# ###########################################
# Greater than 1
# 1.0021603
# ../SincNet/data_lists/DATA/03-01-08-02-02-01-07.wav
# ###########################################
# Lower than -1
# -1.0022268
# ../SincNet/data_lists/DATA/76-57-07-92-75-72-88.wav
# ###########################################
# Lower than -1
# -1.0057019
# ../SincNet/data_lists/DATA/55-46-06-50-24-13-53.wav
# ###########################################
# Greater than 1
# 1.019679
# ../SincNet/data_lists/DATA/82-94-05-50-18-92-43.wav
# ###########################################
# Lower than -1
# -1.0001361
# ../SincNet/data_lists/DATA/80-40-04-16-26-98-24.wav
# ###########################################
# Lower than -1
# -1.0000052
# ../SincNet/data_lists/DATA/03-01-04-01-02-02-16.wav
# ###########################################
# Greater than 1
# 1.0245078
# ../SincNet/data_lists/DATA/89-87-07-67-60-22-29.wav
# ###########################################
# Lower than -1
# -1.0020312
# ../SincNet/data_lists/DATA/03-01-04-02-01-02-02.wav
# ###########################################
# Lower than -1
# -1.0022726
# ../SincNet/data_lists/DATA/54-48-05-98-55-69-29.wav
# ###########################################
# Greater than 1
# 1.0182695
# ../SincNet/data_lists/DATA/54-48-05-98-55-69-29.wav
# ###########################################
# Lower than -1
# -1.0038961
# ../SincNet/data_lists/DATA/73-87-01-79-22-45-90.wav
# ###########################################
# Lower than -1
# -1.0001279
# ../SincNet/data_lists/DATA/48-45-01-58-91-88-80.wav
# ###########################################
# Lower than -1
# -1.0000937
# ../SincNet/data_lists/DATA/03-02-02-01-01-02-05.wav
# ###########################################
# Lower than -1
# -1.0049423
# ../SincNet/data_lists/DATA/11-67-01-21-56-78-82.wav
# ###########################################
# Greater than 1
# 1.0223266
# ../SincNet/data_lists/DATA/92-39-07-62-32-43-15.wav
# ###########################################
# Greater than 1
# 1.0000951
# ../SincNet/data_lists/DATA/03-02-05-01-02-02-15.wav
# ###########################################
# Greater than 1
# 1.0090295
# ../SincNet/data_lists/DATA/14-44-05-70-84-61-19.wav
# ###########################################
# Lower than -1
# -1.000561
# ../SincNet/data_lists/DATA/76-44-08-32-49-57-73.wav
# ###########################################
# Lower than -1
# -1.0008179
# ../SincNet/data_lists/DATA/75-98-04-85-95-83-45.wav
# ###########################################
# Lower than -1
# -1.0019524
# ../SincNet/data_lists/DATA/42-94-03-48-23-26-83.wav
# ###########################################
# Greater than 1
# 1.0017416
# ../SincNet/data_lists/DATA/74-89-06-18-49-13-47.wav
# ###########################################
# Lower than -1
# -1.0025235
# ../SincNet/data_lists/DATA/95-17-06-36-57-96-78.wav
# ###########################################
# Lower than -1
# -1.006446
# ../SincNet/data_lists/DATA/45-66-06-76-42-47-91.wav
# ###########################################
# Greater than 1
# 1.0133569
# ../SincNet/data_lists/DATA/03-02-03-02-02-01-09.wav
# ###########################################
# Lower than -1
# -1.0143349
# ../SincNet/data_lists/DATA/68-63-08-95-13-88-37.wav
# ###########################################
# Lower than -1
# -1.0062168
# ../SincNet/data_lists/DATA/47-27-04-86-19-18-11.wav
# ###########################################
# Lower than -1
# -1.0008467
# ../SincNet/data_lists/DATA/73-52-08-81-25-72-57.wav
# ###########################################
# Greater than 1
# 1.004401
# ../SincNet/data_lists/DATA/03-01-08-01-02-02-01.wav
# ###########################################
# Lower than -1
# -1.006952
# ../SincNet/data_lists/DATA/98-16-07-44-93-35-66.wav
# ###########################################
# Lower than -1
# -1.0027796
# ../SincNet/data_lists/DATA/65-89-06-60-61-23-56.wav
# ###########################################
# Lower than -1
# -1.0002595
# ../SincNet/data_lists/DATA/34-85-04-45-78-65-16.wav
# ###########################################
# Lower than -1
# -1.0024806
# ../SincNet/data_lists/DATA/68-18-04-51-71-40-30.wav
# ###########################################
# Lower than -1
# -1.0057018
# ../SincNet/data_lists/DATA/19-43-08-77-85-41-44.wav
# ###########################################
# Greater than 1
# 1.0010766
# ../SincNet/data_lists/DATA/03-01-07-02-02-02-23.wav
# ###########################################
# Greater than 1
# 1.0176412
# ../SincNet/data_lists/DATA/48-82-03-86-42-30-81.wav
# ###########################################
# Greater than 1
# 1.0081825
# ../SincNet/data_lists/DATA/36-40-07-29-89-19-60.wav
# ###########################################
# Greater than 1
# 1.003629
# ../SincNet/data_lists/DATA/51-44-06-39-79-54-49.wav
# ###########################################
# Lower than -1
# -1.0131751
# ../SincNet/data_lists/DATA/20-59-04-83-68-73-12.wav
# ###########################################
# Lower than -1
# -1.0086157
# ../SincNet/data_lists/DATA/65-80-06-43-14-75-88.wav
# ###########################################
# Lower than -1
# -1.0075493
# ../SincNet/data_lists/DATA/03-01-06-02-01-02-20.wav
# ###########################################
# Greater than 1
# 1.0012025
# ../SincNet/data_lists/DATA/03-02-03-01-01-02-14.wav
# ###########################################
# Greater than 1
# 1.0046935
# ../SincNet/data_lists/DATA/10-56-05-33-57-76-94.wav
# ###########################################
# Lower than -1
# -1.0019461
# ../SincNet/data_lists/DATA/54-56-03-20-17-86-14.wav
# ###########################################
# Lower than -1
# -1.0032048
# ../SincNet/data_lists/DATA/96-17-03-76-40-63-72.wav
# ###########################################
# Lower than -1
# -1.0027262
# ../SincNet/data_lists/DATA/83-91-05-15-69-46-98.wav
# ###########################################
# Lower than -1
# -1.0010777
# ../SincNet/data_lists/DATA/69-84-07-16-50-42-94.wav
# ###########################################
# Lower than -1
# -1.0014687
# ../SincNet/data_lists/DATA/03-01-02-01-01-02-05.wav
# ###########################################
# Lower than -1
# -1.007657
# ../SincNet/data_lists/DATA/35-86-06-75-50-69-47.wav
# ###########################################
# Lower than -1
# -1.000284
# ../SincNet/data_lists/DATA/74-69-06-60-44-28-90.wav
# ###########################################
# Greater than 1
# 1.0011512
# ../SincNet/data_lists/DATA/03-02-03-02-02-02-12.wav
# ###########################################
# Greater than 1
# 1.0028256
# ../SincNet/data_lists/DATA/49-79-07-37-50-96-63.wav
# ###########################################
# Lower than -1
# -1.0030764
# ../SincNet/data_lists/DATA/89-44-05-43-47-95-67.wav
# ###########################################
# Lower than -1
# -1.0048813
# ../SincNet/data_lists/DATA/96-68-08-85-27-34-32.wav
# ###########################################
# Lower than -1
# -1.000199
# ../SincNet/data_lists/DATA/41-48-05-32-62-17-87.wav
# ###########################################
# Lower than -1
# -1.0088737
# ../SincNet/data_lists/DATA/38-78-07-86-42-57-96.wav
# ###########################################
# Lower than -1
# -1.0007522
# ../SincNet/data_lists/DATA/17-42-04-56-69-34-71.wav
# ###########################################
# Greater than 1
# 1.011543
# ../SincNet/data_lists/DATA/03-01-05-01-01-01-20.wav
# ###########################################
# Greater than 1
# 1.0132933
# ../SincNet/data_lists/DATA/34-26-03-51-28-59-83.wav
# ###########################################
# Greater than 1
# 1.0022361
# ../SincNet/data_lists/DATA/17-56-08-23-68-59-57.wav
# ###########################################
# Lower than -1
# -1.0237901
# ../SincNet/data_lists/DATA/74-72-07-53-11-96-28.wav
# ###########################################
# Lower than -1
# -1.0009676
# ../SincNet/data_lists/DATA/12-67-05-68-87-53-47.wav
# ###########################################
# Greater than 1
# 1.0007509
# ../SincNet/data_lists/DATA/03-01-03-01-01-02-20.wav
# ###########################################
# Greater than 1
# 1.0159168
# ../SincNet/data_lists/DATA/49-75-03-10-11-30-67.wav
# ###########################################
# Lower than -1
# -1.0352521
# ../SincNet/data_lists/DATA/81-14-05-75-94-42-44.wav
# ###########################################
# Greater than 1
# 1.0069503
# ../SincNet/data_lists/DATA/03-02-05-02-01-01-13.wav
# ###########################################
# Lower than -1
# -1.0024856
# ../SincNet/data_lists/DATA/03-01-07-01-01-01-09.wav
# ###########################################
# Lower than -1
# -1.0114796
# ../SincNet/data_lists/DATA/90-11-05-10-52-85-50.wav
# ###########################################
# Greater than 1
# 1.0090145
# ../SincNet/data_lists/DATA/90-11-05-10-52-85-50.wav
# ###########################################
# Lower than -1
# -1.0017457
# ../SincNet/data_lists/DATA/03-01-06-01-02-01-19.wav
# ###########################################
# Lower than -1
# -1.0025007
# ../SincNet/data_lists/DATA/72-34-03-86-54-94-84.wav
# ###########################################
# Greater than 1
# 1.01155
# ../SincNet/data_lists/DATA/03-01-05-01-01-01-06.wav
# ###########################################
# Lower than -1
# -1.0029178
# ../SincNet/data_lists/DATA/52-20-04-61-72-70-65.wav
# ###########################################
# Greater than 1
# 1.0157756
# ../SincNet/data_lists/DATA/75-19-05-11-74-85-33.wav
# ###########################################
# Lower than -1
# -1.0002736
# ../SincNet/data_lists/DATA/94-95-07-54-24-69-76.wav
# ###########################################
# Lower than -1
# -1.0033975
# ../SincNet/data_lists/DATA/90-32-04-45-33-76-61.wav
# ###########################################
# Lower than -1
# -1.0007924
# ../SincNet/data_lists/DATA/89-29-04-79-88-87-36.wav
# ###########################################
# Greater than 1
# 1.0170642
# ../SincNet/data_lists/DATA/96-44-08-65-91-11-35.wav
# ###########################################
# Lower than -1
# -1.0169551
# ../SincNet/data_lists/DATA/20-52-01-97-78-66-41.wav
# ###########################################
# Lower than -1
# -1.0028001
# ../SincNet/data_lists/DATA/77-62-07-93-97-26-63.wav
# ###########################################
# Lower than -1
# -1.0047328
# ../SincNet/data_lists/DATA/79-76-04-21-86-12-54.wav
# ###########################################
# Greater than 1
# 1.0051992
# ../SincNet/data_lists/DATA/03-01-02-01-02-01-11.wav
# ###########################################
# Greater than 1
# 1.0034406
# ../SincNet/data_lists/DATA/24-41-06-93-68-36-13.wav
# ###########################################
# Greater than 1
# 1.0050044
# ../SincNet/data_lists/DATA/03-02-03-02-01-01-09.wav
# ###########################################
# Lower than -1
# -1.0001838
# ../SincNet/data_lists/DATA/15-70-04-53-44-23-75.wav
# ###########################################
# Greater than 1
# 1.0139974
# ../SincNet/data_lists/DATA/20-14-05-18-51-36-62.wav
# ###########################################
# Lower than -1
# -1.0016136
# ../SincNet/data_lists/DATA/03-01-08-01-01-02-16.wav
# ###########################################
# Lower than -1
# -1.0097363
# ../SincNet/data_lists/DATA/52-80-03-34-66-30-23.wav
# ###########################################
# Greater than 1
# 1.0027537
# ../SincNet/data_lists/DATA/03-02-03-02-02-01-04.wav
# ###########################################
# Lower than -1
# -1.0077657
# ../SincNet/data_lists/DATA/23-44-03-92-37-95-55.wav
# ###########################################
# Greater than 1
# 1.002624
# ../SincNet/data_lists/DATA/03-01-04-01-02-02-21.wav
# ###########################################
# Greater than 1
# 1.0037767
# ../SincNet/data_lists/DATA/03-01-08-01-02-02-02.wav
# ###########################################
# Lower than -1
# -1.0032985
# ../SincNet/data_lists/DATA/03-02-02-01-02-02-24.wav
# ###########################################
# Greater than 1
# 1.005269
# ../SincNet/data_lists/DATA/28-64-05-31-34-23-41.wav
# ###########################################
# Lower than -1
# -1.0011767
# ../SincNet/data_lists/DATA/85-23-04-86-95-40-18.wav
# ###########################################
# Lower than -1
# -1.0015692
# ../SincNet/data_lists/DATA/35-30-07-76-43-11-42.wav
# ###########################################
# Lower than -1
# -1.0016246
# ../SincNet/data_lists/DATA/32-27-06-36-18-55-16.wav
# ###########################################
# Lower than -1
# -1.0102981
# ../SincNet/data_lists/DATA/34-70-04-87-82-18-86.wav
# ###########################################
# Greater than 1
# 1.0021654
# ../SincNet/data_lists/DATA/03-02-03-01-02-02-20.wav
# ###########################################
# Lower than -1
# -1.0028813
# ../SincNet/data_lists/DATA/03-02-01-01-01-01-17.wav
# ###########################################
# Greater than 1
# 1.0047613
# ../SincNet/data_lists/DATA/45-33-01-13-79-81-59.wav
# ###########################################
# Lower than -1
# -1.0029137
# ../SincNet/data_lists/DATA/03-02-02-01-02-02-20.wav
# ###########################################
# Lower than -1
# -1.0012676
# ../SincNet/data_lists/DATA/03-02-04-02-02-01-24.wav
# ###########################################
# Greater than 1
# 1.0037208
# ../SincNet/data_lists/DATA/88-55-08-72-68-98-44.wav
# ###########################################
# Greater than 1
# 1.0006143
# ../SincNet/data_lists/DATA/83-63-01-92-46-27-42.wav
# ###########################################
# Greater than 1
# 1.0000213
# ../SincNet/data_lists/DATA/03-02-03-01-01-01-21.wav
# ###########################################
# Lower than -1
# -1.0021535
# ../SincNet/data_lists/DATA/21-65-08-28-63-29-72.wav
# ###########################################
# Greater than 1
# 1.0013537
# ../SincNet/data_lists/DATA/03-01-08-02-02-01-23.wav
# ###########################################
# Lower than -1
# -1.0060425
# ../SincNet/data_lists/DATA/13-61-06-11-37-35-14.wav
# ###########################################
# Lower than -1
# -1.0008483
# ../SincNet/data_lists/DATA/03-01-04-02-01-02-19.wav
# ###########################################
# Lower than -1
# -1.0007523
# ../SincNet/data_lists/DATA/87-29-08-76-37-92-59.wav
# ###########################################
# Lower than -1
# -1.0001391
# ../SincNet/data_lists/DATA/50-67-03-37-90-65-80.wav
# ###########################################
# Greater than 1
# 1.0012746
# ../SincNet/data_lists/DATA/17-84-01-48-49-61-67.wav
# ###########################################
# Greater than 1
# 1.0009302
# ../SincNet/data_lists/DATA/56-86-08-68-32-37-38.wav
# ###########################################
# Lower than -1
# -1.0091393
# ../SincNet/data_lists/DATA/28-30-07-16-52-90-19.wav
# ###########################################
# Lower than -1
# -1.0041945
# ../SincNet/data_lists/DATA/47-50-06-43-86-77-32.wav
# ###########################################
# Lower than -1
# -1.0022134
# ../SincNet/data_lists/DATA/84-27-03-34-57-78-59.wav
# ###########################################
# Lower than -1
# -1.023028
# ../SincNet/data_lists/DATA/80-21-01-95-22-34-81.wav
# ###########################################
# Greater than 1
# 1.0026509
# ../SincNet/data_lists/DATA/57-68-08-53-20-56-40.wav
# ###########################################
# Greater than 1
# 1.006625
# ../SincNet/data_lists/DATA/62-57-08-33-73-35-94.wav
# ###########################################
# Lower than -1
# -1.0041174
# ../SincNet/data_lists/DATA/38-21-01-68-15-46-26.wav
# ###########################################
# Greater than 1
# 1.0015149
# ../SincNet/data_lists/DATA/73-54-05-35-79-44-80.wav
# ###########################################
# Greater than 1
# 1.002616
# ../SincNet/data_lists/DATA/03-02-03-02-01-01-05.wav
# ###########################################
# Lower than -1
# -1.002863
# ../SincNet/data_lists/DATA/90-86-08-61-34-38-67.wav
# ###########################################
# Greater than 1
# 1.0098033
# ../SincNet/data_lists/DATA/13-57-06-52-18-40-59.wav
# ###########################################
# Greater than 1
# 1.0045966
# ../SincNet/data_lists/DATA/51-56-07-90-74-47-85.wav
# ###########################################
# Greater than 1
# 1.0053426
# ...
# Lower than -1
# -1.0017843
# ../SincNet/data_lists/DATA/18-90-03-77-86-30-62.wav
# ###########################################
# Lower than -1
# -1.0124843
# ../SincNet/data_lists/DATA/80-65-05-54-94-39-67.wav
# ###########################################
# Lower than -1
# -1.0000329
# ../SincNet/data_lists/DATA/76-94-01-98-26-49-61.wav
# ###########################################
# Lower than -1
# -1.0011172
# ../SincNet/data_lists/DATA/03-02-04-01-01-01-24.wav
# ###########################################
# Lower than -1
# -1.0017139
# ../SincNet/data_lists/DATA/23-24-03-29-11-78-14.wav
# ###########################################
# Greater than 1
# 1.0032958
# ../SincNet/data_lists/DATA/56-19-01-85-44-97-23.wav
# ###########################################
# Greater than 1
# 1.0140897
# ../SincNet/data_lists/DATA/03-01-04-02-01-01-19.wav
# ###########################################
# Greater than 1
# 1.0005571
# ../SincNet/data_lists/DATA/03-01-02-01-01-01-17.wav
# ###########################################
# Lower than -1
# -1.0040059
# ../SincNet/data_lists/DATA/88-36-08-51-46-66-97.wav
# ###########################################
# Lower than -1
# -1.0106174
# ../SincNet/data_lists/DATA/10-45-06-91-48-20-67.wav
# ###########################################
# Greater than 1
# 1.0004016
# ../SincNet/data_lists/DATA/66-73-07-17-51-22-12.wav
# ###########################################
# Greater than 1
# 1.0018582
# ../SincNet/data_lists/DATA/03-01-01-01-01-02-05.wav
# ###########################################
# Lower than -1
# -1.013884
# ../SincNet/data_lists/DATA/45-79-01-68-61-70-18.wav
# ###########################################
# Lower than -1
# -1.0021306
# ../SincNet/data_lists/DATA/91-27-01-17-43-51-45.wav
# ###########################################
# Lower than -1
# -1.0012243
# ../SincNet/data_lists/DATA/36-87-08-93-28-37-45.wav
# ###########################################
# Greater than 1
# 1.0014794
# ../SincNet/data_lists/DATA/03-01-01-01-01-01-17.wav
# ###########################################
# Lower than -1
# -1.018852
# ../SincNet/data_lists/DATA/33-28-08-31-40-82-11.wav
# ###########################################
# Lower than -1
# -1.0006702
# ../SincNet/data_lists/DATA/83-33-08-50-53-46-54.wav
# ###########################################
# Lower than -1
# -1.0192844
# ../SincNet/data_lists/DATA/26-91-05-29-96-69-22.wav
# ###########################################
# Greater than 1
# 1.0159973
# ../SincNet/data_lists/DATA/03-01-05-02-01-01-14.wav
# ###########################################
# Lower than -1
# -1.0015523
# ../SincNet/data_lists/DATA/41-95-04-48-93-63-17.wav
# ###########################################
# Lower than -1
# -1.0262519
# ../SincNet/data_lists/DATA/76-34-08-72-74-44-97.wav
# ###########################################
# Greater than 1
# 1.0045453
# ../SincNet/data_lists/DATA/76-34-08-72-74-44-97.wav
# ###########################################
# Lower than -1
# -1.0235586
# ../SincNet/data_lists/DATA/16-19-05-51-12-90-72.wav
# ###########################################
# Greater than 1
# 1.0003307
# ../SincNet/data_lists/DATA/03-01-02-01-01-01-05.wav
# ###########################################
# Greater than 1
# 1.0089053
# ../SincNet/data_lists/DATA/03-02-01-01-01-01-07.wav
# ###########################################
# Lower than -1
# -1.0018303
# ../SincNet/data_lists/DATA/43-82-01-65-62-77-86.wav
# ###########################################
# Lower than -1
# -1.0012082
# ../SincNet/data_lists/DATA/51-43-03-87-77-47-32.wav
# ###########################################
# Greater than 1
# 1.0140818
# ../SincNet/data_lists/DATA/64-70-05-11-30-69-52.wav
# ###########################################
# Lower than -1
# -1.001096
# ../SincNet/data_lists/DATA/46-89-03-96-26-10-59.wav
# ###########################################
# Greater than 1
# 1.0316364
# ../SincNet/data_lists/DATA/87-42-07-55-10-33-80.wav
# ###########################################
# Lower than -1
# -1.0006795
# ../SincNet/data_lists/DATA/03-02-03-01-01-01-05.wav
# ###########################################
# Lower than -1
# -1.014924
# ../SincNet/data_lists/DATA/83-17-03-49-55-36-77.wav
# ###########################################
# Lower than -1
# -1.0001878
# ../SincNet/data_lists/DATA/75-51-04-50-72-38-62.wav
# ###########################################
# Greater than 1
# 1.0056586
# ../SincNet/data_lists/DATA/03-01-07-02-01-01-02.wav
# ###########################################
# Greater than 1
# 1.0050012
# ../SincNet/data_lists/DATA/03-02-03-02-01-02-24.wav
# ###########################################
# Greater than 1
# 1.0073462
# ../SincNet/data_lists/DATA/03-01-07-01-01-02-09.wav
# ###########################################
# Lower than -1
# -1.0032984
# ../SincNet/data_lists/DATA/73-83-04-94-89-88-76.wav
# ###########################################
# Greater than 1
# 1.0115132
# ../SincNet/data_lists/DATA/24-43-08-55-92-88-50.wav
# ###########################################
# Lower than -1
# -1.0181843
# ../SincNet/data_lists/DATA/55-27-01-48-56-26-63.wav
# ###########################################
# Lower than -1
# -1.0049095
# ../SincNet/data_lists/DATA/73-95-03-91-54-76-81.wav
# ###########################################
# Greater than 1
# 1.0029641
# ../SincNet/data_lists/DATA/03-01-02-02-02-01-21.wav
# ###########################################
# Lower than -1
# -1.0038724
# ../SincNet/data_lists/DATA/10-67-03-98-54-42-11.wav
# ###########################################
# Lower than -1
# -1.013703
# ../SincNet/data_lists/DATA/28-85-05-61-94-53-12.wav
# ###########################################
# Greater than 1
# 1.0042971
# ../SincNet/data_lists/DATA/49-37-06-85-52-62-45.wav
# ###########################################
# Lower than -1
# -1.0063258
# ../SincNet/data_lists/DATA/45-40-01-65-98-25-77.wav
# ###########################################
# Lower than -1
# -1.0106889
# ../SincNet/data_lists/DATA/03-01-07-02-01-01-24.wav
# ###########################################
# Lower than -1
# -1.0002066
# ../SincNet/data_lists/DATA/59-85-08-86-43-78-40.wav
# ###########################################
# Greater than 1
# 1.013491
# ../SincNet/data_lists/DATA/87-96-05-94-30-59-86.wav
# ###########################################
# Greater than 1
# 1.0119313
# ../SincNet/data_lists/DATA/55-19-06-59-95-23-53.wav
# ###########################################
# Lower than -1
# -1.0007651
# ../SincNet/data_lists/DATA/11-53-06-42-88-34-80.wav
# ###########################################
# Lower than -1
# -1.0084518
# ../SincNet/data_lists/DATA/63-98-05-11-61-12-92.wav
# ###########################################
# Greater than 1
# 1.0099164
# ../SincNet/data_lists/DATA/63-98-05-11-61-12-92.wav
# ###########################################
# Lower than -1
# -1.0047051
# ../SincNet/data_lists/DATA/66-62-07-87-46-64-56.wav
# ###########################################
# Lower than -1
# -1.0102948
# ../SincNet/data_lists/DATA/03-01-06-02-02-02-03.wav
# ###########################################
# Lower than -1
# -1.0009851
# ../SincNet/data_lists/DATA/31-46-04-11-42-76-72.wav
# ###########################################
# Greater than 1
# 1.0050035
# ../SincNet/data_lists/DATA/03-01-03-02-02-02-13.wav
# ###########################################
# Lower than -1
# -1.0005567
# ../SincNet/data_lists/DATA/45-57-01-80-91-11-32.wav
# ###########################################
# Lower than -1
# -1.0038295
# ../SincNet/data_lists/DATA/03-02-06-02-02-01-23.wav
# ###########################################
# Lower than -1
# -1.0057712
# ../SincNet/data_lists/DATA/19-79-03-53-62-56-94.wav
# ###########################################
# Lower than -1
# -1.0072653
# ../SincNet/data_lists/DATA/29-66-03-58-10-12-74.wav
# ###########################################
# Greater than 1
# 1.0152954
# ../SincNet/data_lists/DATA/03-01-03-01-02-02-07.wav
# ###########################################
# Lower than -1
# -1.002456
# ../SincNet/data_lists/DATA/23-43-04-10-24-62-73.wav
# ###########################################
# Lower than -1
# -1.0081341
# ../SincNet/data_lists/DATA/21-24-04-30-12-11-35.wav
# ###########################################
# Greater than 1
# 1.0001565
# ../SincNet/data_lists/DATA/03-02-02-01-02-02-01.wav
# ###########################################
# Lower than -1
# -1.0012423
# ../SincNet/data_lists/DATA/03-02-06-02-02-02-16.wav
# ###########################################
# Greater than 1
# 1.0088326
# ../SincNet/data_lists/DATA/03-01-08-01-01-02-20.wav
# ###########################################
# Lower than -1
# -1.002825
# ../SincNet/data_lists/DATA/66-17-03-40-78-77-75.wav
# ###########################################
# Lower than -1
# -1.0007212
# ../SincNet/data_lists/DATA/28-30-01-11-52-77-38.wav
# ###########################################
# Lower than -1
# -1.0019526
# ../SincNet/data_lists/DATA/84-89-07-43-23-17-34.wav
# ###########################################
# Greater than 1
# 1.0063981
# ../SincNet/data_lists/DATA/47-55-08-43-16-34-10.wav
# ###########################################
# Lower than -1
# -1.0006278
# ../SincNet/data_lists/DATA/21-62-06-43-12-85-65.wav
# ###########################################
# Greater than 1
# 1.0018435
# ../SincNet/data_lists/DATA/03-01-04-01-02-01-22.wav
# ###########################################
# Lower than -1
# -1.0024841
# ../SincNet/data_lists/DATA/66-98-01-83-81-62-93.wav
# ###########################################
# Lower than -1
# -1.0044724
# ../SincNet/data_lists/DATA/37-94-03-69-33-55-25.wav
# ###########################################
# Lower than -1
# -1.0015441
# ../SincNet/data_lists/DATA/90-73-08-95-15-79-40.wav
# ###########################################
# Lower than -1
# -1.0001918
# ../SincNet/data_lists/DATA/32-43-06-19-54-83-96.wav
# ###########################################
# Lower than -1
# -1.0097319
# ../SincNet/data_lists/DATA/78-53-03-98-44-28-47.wav
# ###########################################
# Lower than -1
# -1.0053129
# ../SincNet/data_lists/DATA/65-34-03-32-41-82-47.wav
# ###########################################
# Greater than 1
# 1.0017111
# ../SincNet/data_lists/DATA/68-71-08-70-41-76-69.wav
# ###########################################
# Lower than -1
# -1.0074638
# ../SincNet/data_lists/DATA/17-45-06-35-81-72-50.wav
# ###########################################
# Lower than -1
# -1.0103604
# ../SincNet/data_lists/DATA/25-22-08-20-29-28-50.wav
# ###########################################
# Greater than 1
# 1.0014563
# ../SincNet/data_lists/DATA/03-02-01-01-01-01-22.wav
# ###########################################
# Lower than -1
# -1.0019552
# ../SincNet/data_lists/DATA/96-62-08-77-37-94-89.wav
# ###########################################
# Greater than 1
# 1.0001631
# ../SincNet/data_lists/DATA/03-02-02-02-01-01-05.wav
# ###########################################
# Greater than 1
# 1.0009975
# ../SincNet/data_lists/DATA/03-01-07-02-02-01-21.wav
# ###########################################
# Greater than 1
# 1.0155491
# ../SincNet/data_lists/DATA/03-02-03-01-02-01-06.wav
# ###########################################
# Lower than -1
# -1.0011529
# ../SincNet/data_lists/DATA/85-48-04-84-90-89-35.wav
# ###########################################
# Lower than -1
# -1.0011809
# ../SincNet/data_lists/DATA/58-82-08-15-85-40-65.wav
# ###########################################
# Lower than -1
# -1.0018752
# ../SincNet/data_lists/DATA/86-98-01-45-62-16-12.wav
# ###########################################
# Greater than 1
# 1.004608
# ../SincNet/data_lists/DATA/14-97-08-84-32-78-71.wav
# ###########################################
# Lower than -1
# -1.0028191
# ../SincNet/data_lists/DATA/23-10-01-56-73-82-30.wav
# ###########################################
# Lower than -1
# -1.0022818
# ../SincNet/data_lists/DATA/65-15-07-73-17-64-37.wav
# ###########################################
# Lower than -1
# -1.0211923
# ../SincNet/data_lists/DATA/41-38-03-45-36-85-65.wav
# ###########################################
# Lower than -1
# -1.003207
# ../SincNet/data_lists/DATA/83-69-04-45-65-67-42.wav
# ###########################################
# Lower than -1
# -1.0085357
# ../SincNet/data_lists/DATA/67-25-03-28-83-63-96.wav
# ###########################################
# Lower than -1
# -1.0007737
# ../SincNet/data_lists/DATA/71-54-08-36-27-44-53.wav
# ###########################################
# Lower than -1
# -1.0003837
# ../SincNet/data_lists/DATA/64-41-07-91-37-22-46.wav
# ###########################################
# Lower than -1
# -1.0014236
# ../SincNet/data_lists/DATA/32-83-05-77-28-67-42.wav
# ###########################################
# Lower than -1
# -1.0042765
# ../SincNet/data_lists/DATA/20-19-06-50-34-32-16.wav
# ###########################################
# Greater than 1
# 1.0041225
# ../SincNet/data_lists/DATA/45-86-01-10-21-48-85.wav
# ###########################################
# Lower than -1
# -1.0000399
# ../SincNet/data_lists/DATA/82-10-01-57-11-43-40.wav
# ###########################################
# Greater than 1
# 1.0046452
# ../SincNet/data_lists/DATA/03-01-08-02-01-01-01.wav
# ###########################################
# Lower than -1
# -1.0008197
# ../SincNet/data_lists/DATA/03-01-05-01-01-02-01.wav
# ###########################################
# Lower than -1
# -1.0004604
# ../SincNet/data_lists/DATA/58-82-03-83-15-93-14.wav
# ###########################################
# Lower than -1
# -1.0057124
# ../SincNet/data_lists/DATA/26-75-04-32-61-38-34.wav
# ###########################################
# Lower than -1
# -1.0015887
# ../SincNet/data_lists/DATA/03-01-05-01-02-02-18.wav
# ###########################################
# Lower than -1
# -1.0010111
# ../SincNet/data_lists/DATA/03-01-07-02-02-01-14.wav
# ###########################################
# Lower than -1
# -1.0038186
# ../SincNet/data_lists/DATA/27-16-04-84-85-36-15.wav
# ###########################################
# Lower than -1
# -1.0009598
# ../SincNet/data_lists/DATA/40-51-04-35-22-84-56.wav
# ###########################################
# Lower than -1
# -1.0126483
# ../SincNet/data_lists/DATA/73-79-05-72-49-32-26.wav
# ###########################################
# Lower than -1
# -1.0136131
# ../SincNet/data_lists/DATA/03-01-02-02-01-01-18.wav
# ###########################################
# Lower than -1
# -1.0039889
# ../SincNet/data_lists/DATA/18-36-05-38-37-81-53.wav
# ###########################################
# Lower than -1
# -1.0019091
# ../SincNet/data_lists/DATA/58-47-03-71-12-34-55.wav
# ###########################################
# Lower than -1
# -1.0012615
# ../SincNet/data_lists/DATA/73-25-01-50-38-84-56.wav
# ###########################################
# Lower than -1
# -1.0038545
# ../SincNet/data_lists/DATA/20-50-07-78-71-24-44.wav
# ###########################################
# Greater than 1
# 1.0047414
# ../SincNet/data_lists/DATA/87-29-07-11-62-71-59.wav
# ###########################################
# Greater than 1
# 1.0018708
# ../SincNet/data_lists/DATA/03-01-05-01-02-02-22.wav
# ###########################################
# Greater than 1
# 1.0029646
# ../SincNet/data_lists/DATA/03-01-02-02-01-01-15.wav
# ###########################################
# Lower than -1
# -1.0036461
# ../SincNet/data_lists/DATA/19-33-04-79-91-51-53.wav
# ###########################################
# Lower than -1
# -1.0131602
# ../SincNet/data_lists/DATA/45-61-04-57-77-71-32.wav
# ###########################################
# Lower than -1
# -1.0062647
# ../SincNet/data_lists/DATA/72-82-03-70-37-67-28.wav
# ###########################################
# Greater than 1
# 1.0076095
# ../SincNet/data_lists/DATA/64-13-07-89-71-82-24.wav
# ###########################################
# Greater than 1
# 1.0022668
# ../SincNet/data_lists/DATA/03-02-03-02-02-02-02.wav
# ###########################################
# Greater than 1
# 1.0078555
# ../SincNet/data_lists/DATA/03-01-03-02-02-01-14.wav
# ###########################################
# Lower than -1
# -1.006128
# ../SincNet/data_lists/DATA/78-61-08-29-94-74-77.wav
# ###########################################
# Lower than -1
# -1.0044143
# ../SincNet/data_lists/DATA/46-79-01-36-97-14-42.wav
# ###########################################
# Greater than 1
# 1.0116161
# ../SincNet/data_lists/DATA/38-98-08-68-57-70-89.wav
# ###########################################
# Lower than -1
# -1.0105428
# ../SincNet/data_lists/DATA/03-01-06-01-01-01-03.wav
# ###########################################
# Greater than 1
# 1.0207968
# ../SincNet/data_lists/DATA/03-01-03-02-01-01-10.wav
# ###########################################
# Greater than 1
# 1.0051284
# ../SincNet/data_lists/DATA/51-58-07-90-91-69-26.wav
# ###########################################
# Lower than -1
# -1.0051843
# ../SincNet/data_lists/DATA/42-84-07-69-87-66-28.wav
# ###########################################

# %%
X1D_a = np.asarray(X1D)
X2D_a = np.asarray(X2D)
y_a = np.asarray(y)

# %%
print(X1D_a.shape)
print(X2D_a.shape)
print(y_a.shape)
# Out:
# (5252, 40)
# (5252, 275, 40)
# (5252,)

# %%
X1_name = "../feats/padded_mfcc/X1D_Wiktor_norm.joblib"
X2_name = "../feats/padded_mfcc/X2D_Wiktor_norm.joblib"
y_name = "../feats/padded_mfcc/y_Wiktor_norm.joblib"

joblib.dump(X1D_a, X1_name)
joblib.dump(X2D_a, X2_name)
joblib.dump(y_a, y_name)
# Out:
# ['../feats/padded_mfcc/y_Wiktor_norm.joblib']

# %%
X_name = '../feats/padded_signal_list.joblib'

joblib.dump(XX, X_name)
# Out:
# ['../feats/padded_signal_list.joblib']

# %%
XX_loaded = joblib.load('../feats/padded_signal_list.joblib')

# %%
type(XX_loaded)
# Out:
# list

# %%
XX_np = np.asarray(XX_loaded)

# %%
len(XX_loaded[233])
# Out:
# 140526

# %%
my_df = pd.DataFrame(XX_loaded)

# %%
import csv

with open("padded_signal_list.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(XX_loaded)

# %%
from numpy import genfromtxt
my_data = genfromtxt('padded_signal_list.csv', delimiter=',')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-89fd70a77832>", line 2, in <module>
#     my_data = genfromtxt('padded_signal_list.csv', delimiter=',')
#   File "/opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py", line 2039, in genfromtxt
#     values = split_line(line)
#   File "/opt/conda/lib/python3.7/site-packages/numpy/lib/_iotools.py", line 273, in __call__
#     return self._handyman(_decode_line(line, self.encoding))
#   File "/opt/conda/lib/python3.7/site-packages/numpy/lib/_iotools.py", line 249, in _delimited_splitter
#     return line.split(self.delimiter)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/conda/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/conda/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/conda/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/conda/lib/python3.7/inspect.py", line 732, in getmodule
#     for modname, module in list(sys.modules.items()):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
